# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
h=0.001
#Primero definimos una h, que sera el tiempo en el cual nuestro programa
w=(9.81/10)**.5
n=100000
v = np.zeros(n)
O = np.zeros(n)
v[0]=0.1

for i in range(n-1):
    v[i+1] = v[i] - h*(w**2)*O[i]
    O[i+1] = O[i] + h*v[i]

# %%
plt.plot(O)
plt.xlabel('Tiempo')
plt.ylabel('Angulo')
plt.grid()

# %%
plt.plot(v,O)
plt.xlabel('Velocidad')
plt.ylabel('Angulo')
plt.grid()

# %%
plt.plot(v)
plt.xlabel('Tiempo')
plt.ylabel('Velocidad')
plt.grid()
